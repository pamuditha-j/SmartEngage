# %%
import tensorflow as tf
import numpy as np
import mediapipe as mp
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers.legacy import Adam
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from tqdm import tqdm
from math import ceil
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow.keras.layers as kl
import cv2

mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def detect_and_crop_eye_region(image):
    # gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = image.astype(np.uint8)

    # if len(image.shape) == 2:
    #     print("Image is in grayscale format (CV_8U)")
    # elif len(image.shape) == 3:
    #     print("Image is in color format (CV_8UC3)")
    #     print(image.shape)
    #     # If you want to check if the image is in BGR or RGB format
    #     if image.shape[2] == 3:
    #         print("Image is in BGR color format")
    #     elif image.shape[2] == 4:
    #         print("Image is in RGBA color format")
    # else:
    #     print("Unknown image format")

    # # Detect faces using Haarcascade
    # faces = face_cascade.detectMultiScale(image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    try:
        for i in range(30):
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            results = face_mesh.process(image_rgb)
            if results.multi_face_landmarks:
                # print('face found')
                # Extract the first face landmarks (assuming only one face per image)
                face_landmarks = results.multi_face_landmarks[0]

                # Extract landmark points
                landmark_points = [(lm.x * image.shape[1], lm.y * image.shape[0]) for lm in face_landmarks.landmark]

                # Convert the landmark points to NumPy array
                landmark_points = np.array(landmark_points)

                # Extract eyes region
                eyes_roi = image[min(int(landmark_points[67, 1]), int(landmark_points[10, 1]), int(landmark_points[297, 1])):max(int(landmark_points[118, 1]),int(landmark_points[346, 1])),
                            int(landmark_points[162, 0]):int(landmark_points[389, 0])]

                mouth_roi = image[int(landmark_points[4, 1]):int(landmark_points[200, 1]),
                            int(landmark_points[132, 0]):int(landmark_points[361, 0])]

                # print("Size of eyes_roi before resize:", eyes_roi.shape)
                # if len(eyes_roi) > 0:
                #     eyes_roi = cv2.resize(eyes_roi, (144, 50))
                #     print("Size of eyes_roi after resize:", eyes_roi.shape)
                # else:
                #     print("Eyes region is empty. Skipping resizing.")
                # print("Size of mouth before resize:", mouth_roi.shape)
                # if len(mouth_roi) > 0:
                #     eyes_roi = cv2.resize(eyes_roi, (144, 50))
                #     print("Size of mouth_roi after resize:", eyes_roi.shape)
                # else:
                #     print("Eyes region is empty. Skipping resizing.")

                # Resize eyes and mouth regions to a fixed size (adjust as needed)

                eyes_roi = cv2.resize(eyes_roi, (48, 24))
                mouth_roi = cv2.resize(mouth_roi, (48, 24))

                # Combine individual ROIs into a single image
                combined_image = np.hstack((eyes_roi, mouth_roi))

                # Resize the combined image to the desired size (adjust as needed)
                combined_image = cv2.resize(combined_image, (96, 24))
                # combined_image = cv2.cvtColor(face_region, cv2.COLOR_BGR2GRAY)

                return combined_image
                # else:
                #     return None
        return None
    except cv2.error as e:
        # print("Error extracting roi:")
        return None

def preprocess_data():
    data = pd.read_csv('../Dataset/fer2013/fer2013.csv')
    labels = pd.read_csv('../Dataset/fer2013/fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    X = np.zeros((n_samples, w, h, 1))


    new_pixel_values = []
    count = 0

    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    # Extract and save eye regions
    for i in tqdm(range(n_samples), desc='Processing images', unit='image'):
        img = X[i].reshape((48, 48, 1))

        # tqdm.write(f'Processing image {i + 1}/{n_samples}', end='\r')
        # print(img)
        extracted_image = detect_and_crop_eye_region(img)

        if extracted_image is not None:
            count += 1
            pixel_values = extracted_image.tobytes()
            new_pixel_values.append(pixel_values)

        else:
            new_pixel_values.append(None)

    data['pixels'] = new_pixel_values

    # Get the indices of rows with non-empty pixel values
    non_empty_indices = data.index[data['pixels'].notnull()]
    print(non_empty_indices)

    # Filter labels dataframe based on non-empty pixel values indices
    labels = labels.iloc[non_empty_indices]

    print(len(labels))

    # Drop rows where the pixel values column has empty strings
    data.dropna(subset=['pixels'], inplace=True)

    # Reset index after dropping rows
    data.reset_index(drop=True, inplace=True)

    data.to_csv('new_data.csv', index=False)

    print('Extracted images count: ', count)

    n_samples = len(data)  
    X1 = np.zeros((n_samples, 24, 96, 1))

    for i in range(n_samples):
        # X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((w, h, 1))
        img_array_loaded = np.frombuffer(data['pixels'][i], dtype=np.uint8)
        X1[i] = img_array_loaded.reshape((24, 96, 1))
        
    plt.imshow(X1[i])
    plt.title('CC Image')
    plt.axis('off')
    plt.show()

    y = np.array(labels[orig_class_names])

    return X1, y



def clean_and_normalize_data(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    # Using mask to remove unknown and NF images
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

    #Add contempt to neutral and remove it
    y[:, 0] += y[:, 7]
    y = y[:, :7]

    # Using mask to remove disgust and fear images
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('disgust')
    X = X[mask]
    y = y[mask]

    # Convert to probabilities between 0 and 1
    y = y[:, :-2] * 0.1

    # Normalize image vectors
    X = X.astype('float64') / 255.0

    return X, y


def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

    # Split Data
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test


def data_augmentation(x_train):
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        zoom_range=0.2
    )
    datagen.fit(x_train)
    return datagen


def graphs(history):
    #Accuracy graph
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('accuracy')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

    #Loss graph
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()


def plot_images(images, labels, title):
    plt.figure(figsize=(10, 10))
    for i in range(min(len(images), 9)):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        plt.title(f'Label: {labels[i]}')
        plt.axis('off')
    plt.suptitle(title)
    plt.show()


def model():    
    model = tf.keras.Sequential()

    model.add(kl.InputLayer(input_shape=(24, 96, 1)))
    model.add(kl.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(kl.BatchNormalization())
    model.add(kl.MaxPooling2D(pool_size=(2, 2)))
    # First conv block
    model.add(kl.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
    model.add(kl.BatchNormalization())
    model.add(kl.MaxPooling2D(pool_size=(2, 2)))
    # model.add(kl.Dropout(0.4))
    
    # Second conv block
    model.add(kl.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
    model.add(kl.BatchNormalization())
    model.add(kl.MaxPooling2D(pool_size=(2, 2)))
    # model.add(kl.Dropout(0.4))
    
    # Third conv block
    model.add(kl.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
    model.add(kl.BatchNormalization())
    model.add(kl.MaxPooling2D(pool_size=(2, 2)))
    # model.add(kl.Dropout(0.4))
    
    # model.add(kl.Conv2D(filters=1024, kernel_size=3, padding='same', activation='relu'))
    # model.add(kl.BatchNormalization())
    # model.add(kl.MaxPooling2D(pool_size=(2, 2)))
    model.add(kl.Dropout(0.2))
    # Flatten
    model.add(kl.Flatten())
    
    # First FC
    model.add(kl.Dense(1024))
    # Second Fc
    model.add(kl.Dense(512))
    # model.add(kl.Dense(256))
    # Output FC with sigmoid at the end
    model.add(kl.Dense(5, activation='softmax', name='prediction'))

    return model


def saveModelWeights(model, test_acc):
    # Serialize and save model to JSON
    model_name = f'basic_emotion_model_{test_acc:.4f}'
    model_json = model.to_json()
    with open(f'{model_name}.json', 'w') as json_file:
        json_file.write(model_json)
    # Save weights to JSON
    model.save_weights(f'{model_name}.h5')

# %%
fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger']

X, y = preprocess_data()
X, y = clean_and_normalize_data(X, y)
x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
datagen = data_augmentation(x_train)
# Out:
# Processing images: 100%|██████████| 35887/35887 [06:43<00:00, 88.87image/s]
# Index([    1,     2,     4,     5,     7,     8,     9,    10,    11,    12,
#        ...
#        35877, 35878, 35879, 35880, 35881, 35882, 35883, 35884, 35885, 35886],
#       dtype='int64', length=30230)
# 30230
# Extracted images count:  30230

# %%
 # n_samples = len(data)
# w = 56
# h = 80
# 
# # Get the indices of rows with non-empty pixel values
# non_empty_indices = data.index[data['pixels'].notna()]
# 
# # Filter labels dataframe based on non-empty pixel values indices
# labels = labels.iloc[non_empty_indices]
# 
# # Drop rows where the pixel values column has empty strings
# data.dropna(subset=['pixels'], inplace=True)
# 
# # Reset index after dropping rows
# data.reset_index(drop=True, inplace=True)
# 
# data.to_csv('new_data.csv', index=False)
# 
# print('Extracted images count: ', count)
# 
# # n_samples = len(data)  
# # X1 = np.zeros((n_samples, 56, 80, 1))
# # 
# # for i in range(n_samples):
# #     # X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((w, h, 1))
# #     img_array_loaded = np.frombuffer(data['pixels'][i], dtype=np.uint8)
# #     X1[i] = img_array_loaded.reshape((56, 80, 1))
#     
# orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
#                         'unknown', 'NF']
# 
# y = np.array(labels[orig_class_names])
# 
# X, y = clean_and_normalize_data(X1, y)
# x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
# datagen = data_augmentation(x_train)

# %%
epochs = 100
batch_size = 32

earlyStopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True
)

lrScheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1
)

callbacks = [
    earlyStopping,
    lrScheduler,
]

# print(x_train)

model = model()
model.summary()
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

print(x_train[0].shape)

plt.imshow(x_train[0])
plt.title('Combined Image')
plt.axis('off')
plt.show()

history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                    steps_per_epoch=len(x_train) // batch_size,
                    validation_data=(x_val, y_val), verbose=2,
                    callbacks=callbacks)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_83 (Conv2D)          (None, 24, 96, 64)        640
#
#  batch_normalization_63 (Ba  (None, 24, 96, 64)        256
#  tchNormalization)
#
#  max_pooling2d_67 (MaxPooli  (None, 12, 48, 64)        0
#  ng2D)
#
#  conv2d_84 (Conv2D)          (None, 12, 48, 128)       73856
#
#  batch_normalization_64 (Ba  (None, 12, 48, 128)       512
#  tchNormalization)
#
#  max_pooling2d_68 (MaxPooli  (None, 6, 24, 128)        0
#  ng2D)
#
#  conv2d_85 (Conv2D)          (None, 6, 24, 256)        295168
#
#  batch_normalization_65 (Ba  (None, 6, 24, 256)        1024
#  tchNormalization)
#
#  max_pooling2d_69 (MaxPooli  (None, 3, 12, 256)        0
#  ng2D)
#
#  conv2d_86 (Conv2D)          (None, 3, 12, 512)        1180160
#
#  batch_normalization_66 (Ba  (None, 3, 12, 512)        2048
#  tchNormalization)
#
#  max_pooling2d_70 (MaxPooli  (None, 1, 6, 512)         0
#  ng2D)
#
#  dropout_38 (Dropout)        (None, 1, 6, 512)         0
#
#  flatten_15 (Flatten)        (None, 3072)              0
#
#  dense_34 (Dense)            (None, 1024)              3146752
#
#  dense_35 (Dense)            (None, 512)               524800
#
#  prediction (Dense)          (None, 5)                 2565
#
# =================================================================
# Total params: 5227781 (19.94 MB)
# Trainable params: 5225861 (19.94 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________
# (24, 96, 1)
# Epoch 1/100
# 727/727 - 56s - loss: 0.5257 - accuracy: 0.3406 - val_loss: 0.4411 - val_accuracy: 0.4102 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 2/100
# 727/727 - 54s - loss: 0.4489 - accuracy: 0.3776 - val_loss: 0.4336 - val_accuracy: 0.4288 - lr: 1.0000e-04 - 54s/epoch - 74ms/step
# Epoch 3/100
# 727/727 - 56s - loss: 0.4424 - accuracy: 0.3925 - val_loss: 0.4344 - val_accuracy: 0.4586 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 4/100
# 727/727 - 56s - loss: 0.4380 - accuracy: 0.4090 - val_loss: 0.4034 - val_accuracy: 0.4936 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 5/100
# 727/727 - 56s - loss: 0.4332 - accuracy: 0.4245 - val_loss: 0.3903 - val_accuracy: 0.5565 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 6/100
# 727/727 - 59s - loss: 0.4294 - accuracy: 0.4346 - val_loss: 0.4241 - val_accuracy: 0.4861 - lr: 1.0000e-04 - 59s/epoch - 81ms/step
# Epoch 7/100
# 727/727 - 56s - loss: 0.4246 - accuracy: 0.4542 - val_loss: 0.3652 - val_accuracy: 0.6097 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 8/100
# 727/727 - 56s - loss: 0.4177 - accuracy: 0.4696 - val_loss: 0.3475 - val_accuracy: 0.6481 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 9/100
# 727/727 - 56s - loss: 0.4119 - accuracy: 0.4841 - val_loss: 0.3484 - val_accuracy: 0.6382 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 10/100
# 727/727 - 56s - loss: 0.4065 - accuracy: 0.4958 - val_loss: 0.3499 - val_accuracy: 0.6097 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 11/100
# 727/727 - 56s - loss: 0.4013 - accuracy: 0.5096 - val_loss: 0.3579 - val_accuracy: 0.6021 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 12/100
# 727/727 - 58s - loss: 0.3962 - accuracy: 0.5209 - val_loss: 0.3223 - val_accuracy: 0.6917 - lr: 1.0000e-04 - 58s/epoch - 80ms/step
# Epoch 13/100
# 727/727 - 56s - loss: 0.3927 - accuracy: 0.5287 - val_loss: 0.3369 - val_accuracy: 0.6680 - lr: 1.0000e-04 - 56s/epoch - 78ms/step
# Epoch 14/100
# 727/727 - 56s - loss: 0.3895 - accuracy: 0.5397 - val_loss: 0.3211 - val_accuracy: 0.6866 - lr: 1.0000e-04 - 56s/epoch - 76ms/step
# Epoch 15/100
# 727/727 - 57s - loss: 0.3857 - accuracy: 0.5459 - val_loss: 0.3167 - val_accuracy: 0.6900 - lr: 1.0000e-04 - 57s/epoch - 78ms/step
# Epoch 16/100
# 727/727 - 55s - loss: 0.3834 - accuracy: 0.5492 - val_loss: 0.3067 - val_accuracy: 0.7147 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 17/100
# 727/727 - 55s - loss: 0.3803 - accuracy: 0.5544 - val_loss: 0.3045 - val_accuracy: 0.7278 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 18/100
# 727/727 - 57s - loss: 0.3780 - accuracy: 0.5644 - val_loss: 0.2980 - val_accuracy: 0.7271 - lr: 1.0000e-04 - 57s/epoch - 79ms/step
# Epoch 19/100
# 727/727 - 55s - loss: 0.3757 - accuracy: 0.5668 - val_loss: 0.3042 - val_accuracy: 0.7206 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 20/100
# 727/727 - 55s - loss: 0.3725 - accuracy: 0.5679 - val_loss: 0.2962 - val_accuracy: 0.7336 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 21/100
# 727/727 - 56s - loss: 0.3685 - accuracy: 0.5787 - val_loss: 0.2930 - val_accuracy: 0.7415 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 22/100
# 727/727 - 55s - loss: 0.3688 - accuracy: 0.5797 - val_loss: 0.2896 - val_accuracy: 0.7518 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 23/100
# 727/727 - 56s - loss: 0.3667 - accuracy: 0.5880 - val_loss: 0.2973 - val_accuracy: 0.7295 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 24/100
# 727/727 - 58s - loss: 0.3661 - accuracy: 0.5836 - val_loss: 0.2920 - val_accuracy: 0.7508 - lr: 1.0000e-04 - 58s/epoch - 80ms/step
# Epoch 25/100
# 727/727 - 55s - loss: 0.3641 - accuracy: 0.5906 - val_loss: 0.2837 - val_accuracy: 0.7566 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 26/100
# 727/727 - 55s - loss: 0.3614 - accuracy: 0.5917 - val_loss: 0.2866 - val_accuracy: 0.7535 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 27/100
# 727/727 - 55s - loss: 0.3595 - accuracy: 0.5981 - val_loss: 0.2828 - val_accuracy: 0.7439 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 28/100
# 727/727 - 55s - loss: 0.3595 - accuracy: 0.5991 - val_loss: 0.2922 - val_accuracy: 0.7319 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 29/100
# 727/727 - 58s - loss: 0.3583 - accuracy: 0.5962 - val_loss: 0.2823 - val_accuracy: 0.7542 - lr: 1.0000e-04 - 58s/epoch - 80ms/step
# Epoch 30/100
# 727/727 - 56s - loss: 0.3562 - accuracy: 0.6090 - val_loss: 0.2844 - val_accuracy: 0.7580 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 31/100
# 727/727 - 56s - loss: 0.3558 - accuracy: 0.6021 - val_loss: 0.2933 - val_accuracy: 0.7329 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 32/100
# 727/727 - 56s - loss: 0.3552 - accuracy: 0.6034 - val_loss: 0.2811 - val_accuracy: 0.7628 - lr: 1.0000e-04 - 56s/epoch - 76ms/step
# Epoch 33/100
# 727/727 - 55s - loss: 0.3527 - accuracy: 0.6139 - val_loss: 0.2740 - val_accuracy: 0.7710 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 34/100
# 727/727 - 56s - loss: 0.3520 - accuracy: 0.6136 - val_loss: 0.2813 - val_accuracy: 0.7645 - lr: 1.0000e-04 - 56s/epoch - 77ms/step
# Epoch 35/100
# 727/727 - 57s - loss: 0.3508 - accuracy: 0.6115 - val_loss: 0.2719 - val_accuracy: 0.7762 - lr: 1.0000e-04 - 57s/epoch - 79ms/step
# Epoch 36/100
# 727/727 - 55s - loss: 0.3509 - accuracy: 0.6166 - val_loss: 0.2734 - val_accuracy: 0.7834 - lr: 1.0000e-04 - 55s/epoch - 76ms/step
# Epoch 37/100
# 727/727 - 36s - loss: 0.3497 - accuracy: 0.6178 - val_loss: 0.2701 - val_accuracy: 0.7837 - lr: 1.0000e-04 - 36s/epoch - 49ms/step
# Epoch 38/100
# 727/727 - 31s - loss: 0.3480 - accuracy: 0.6193 - val_loss: 0.2808 - val_accuracy: 0.7618 - lr: 1.0000e-04 - 31s/epoch - 43ms/step
# Epoch 39/100
# 727/727 - 31s - loss: 0.3465 - accuracy: 0.6234 - val_loss: 0.2681 - val_accuracy: 0.7885 - lr: 1.0000e-04 - 31s/epoch - 43ms/step
# Epoch 40/100
# 727/727 - 32s - loss: 0.3449 - accuracy: 0.6226 - val_loss: 0.2722 - val_accuracy: 0.7731 - lr: 1.0000e-04 - 32s/epoch - 44ms/step
# Epoch 41/100
# 727/727 - 32s - loss: 0.3462 - accuracy: 0.6267 - val_loss: 0.2786 - val_accuracy: 0.7645 - lr: 1.0000e-04 - 32s/epoch - 44ms/step
# Epoch 42/100
# 727/727 - 32s - loss: 0.3445 - accuracy: 0.6286 - val_loss: 0.2697 - val_accuracy: 0.7844 - lr: 1.0000e-04 - 32s/epoch - 44ms/step
# Epoch 43/100
# 727/727 - 33s - loss: 0.3448 - accuracy: 0.6283 - val_loss: 0.2712 - val_accuracy: 0.7885 - lr: 1.0000e-04 - 33s/epoch - 45ms/step
# Epoch 44/100
# 727/727 - 33s - loss: 0.3442 - accuracy: 0.6311 - val_loss: 0.2712 - val_accuracy: 0.7813 - lr: 1.0000e-04 - 33s/epoch - 45ms/step
# Epoch 45/100
# 727/727 - 34s - loss: 0.3424 - accuracy: 0.6354 - val_loss: 0.2676 - val_accuracy: 0.7927 - lr: 1.0000e-04 - 34s/epoch - 47ms/step
# Epoch 46/100
# 727/727 - 35s - loss: 0.3427 - accuracy: 0.6295 - val_loss: 0.2681 - val_accuracy: 0.7899 - lr: 1.0000e-04 - 35s/epoch - 48ms/step
# Epoch 47/100
# 727/727 - 36s - loss: 0.3418 - accuracy: 0.6375 - val_loss: 0.2687 - val_accuracy: 0.7837 - lr: 1.0000e-04 - 36s/epoch - 50ms/step
# Epoch 48/100
# 727/727 - 37s - loss: 0.3410 - accuracy: 0.6353 - val_loss: 0.2662 - val_accuracy: 0.7913 - lr: 1.0000e-04 - 37s/epoch - 51ms/step
# Epoch 49/100
# 727/727 - 37s - loss: 0.3398 - accuracy: 0.6354 - val_loss: 0.2686 - val_accuracy: 0.7872 - lr: 1.0000e-04 - 37s/epoch - 51ms/step
# Epoch 50/100
# 727/727 - 37s - loss: 0.3401 - accuracy: 0.6419 - val_loss: 0.2706 - val_accuracy: 0.7927 - lr: 1.0000e-04 - 37s/epoch - 51ms/step
# Epoch 51/100
# 727/727 - 37s - loss: 0.3387 - accuracy: 0.6405 - val_loss: 0.2669 - val_accuracy: 0.7803 - lr: 1.0000e-04 - 37s/epoch - 51ms/step
# Epoch 52/100
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 727/727 - 38s - loss: 0.3388 - accuracy: 0.6401 - val_loss: 0.2647 - val_accuracy: 0.7861 - lr: 1.0000e-04 - 38s/epoch - 52ms/step
# Epoch 53/100
# 727/727 - 39s - loss: 0.3351 - accuracy: 0.6488 - val_loss: 0.2608 - val_accuracy: 0.7988 - lr: 5.0000e-05 - 39s/epoch - 54ms/step
# Epoch 54/100
# 727/727 - 39s - loss: 0.3323 - accuracy: 0.6503 - val_loss: 0.2602 - val_accuracy: 0.7957 - lr: 5.0000e-05 - 39s/epoch - 53ms/step
# Epoch 55/100
# 727/727 - 38s - loss: 0.3318 - accuracy: 0.6523 - val_loss: 0.2627 - val_accuracy: 0.7999 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 56/100
# 727/727 - 38s - loss: 0.3328 - accuracy: 0.6501 - val_loss: 0.2584 - val_accuracy: 0.8047 - lr: 5.0000e-05 - 38s/epoch - 52ms/step
# Epoch 57/100
# 727/727 - 38s - loss: 0.3314 - accuracy: 0.6541 - val_loss: 0.2592 - val_accuracy: 0.8054 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 58/100
# 727/727 - 38s - loss: 0.3300 - accuracy: 0.6585 - val_loss: 0.2627 - val_accuracy: 0.7954 - lr: 5.0000e-05 - 38s/epoch - 52ms/step
# Epoch 59/100
# 727/727 - 38s - loss: 0.3309 - accuracy: 0.6580 - val_loss: 0.2590 - val_accuracy: 0.7944 - lr: 5.0000e-05 - 38s/epoch - 52ms/step
# Epoch 60/100
# 727/727 - 38s - loss: 0.3312 - accuracy: 0.6545 - val_loss: 0.2608 - val_accuracy: 0.7937 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 61/100
# 727/727 - 38s - loss: 0.3301 - accuracy: 0.6587 - val_loss: 0.2604 - val_accuracy: 0.7964 - lr: 5.0000e-05 - 38s/epoch - 52ms/step
# Epoch 62/100
# 727/727 - 38s - loss: 0.3303 - accuracy: 0.6600 - val_loss: 0.2613 - val_accuracy: 0.8060 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 63/100
# 727/727 - 38s - loss: 0.3297 - accuracy: 0.6577 - val_loss: 0.2596 - val_accuracy: 0.8019 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 64/100
# 727/727 - 38s - loss: 0.3300 - accuracy: 0.6556 - val_loss: 0.2606 - val_accuracy: 0.7968 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 65/100
# 727/727 - 39s - loss: 0.3288 - accuracy: 0.6568 - val_loss: 0.2594 - val_accuracy: 0.8112 - lr: 5.0000e-05 - 39s/epoch - 54ms/step
# Epoch 66/100
# 727/727 - 40s - loss: 0.3281 - accuracy: 0.6603 - val_loss: 0.2565 - val_accuracy: 0.8064 - lr: 5.0000e-05 - 40s/epoch - 55ms/step
# Epoch 67/100
# 727/727 - 40s - loss: 0.3282 - accuracy: 0.6651 - val_loss: 0.2572 - val_accuracy: 0.8108 - lr: 5.0000e-05 - 40s/epoch - 55ms/step
# Epoch 68/100
# 727/727 - 39s - loss: 0.3273 - accuracy: 0.6626 - val_loss: 0.2562 - val_accuracy: 0.8084 - lr: 5.0000e-05 - 39s/epoch - 54ms/step
# Epoch 69/100
# 727/727 - 39s - loss: 0.3276 - accuracy: 0.6642 - val_loss: 0.2578 - val_accuracy: 0.8084 - lr: 5.0000e-05 - 39s/epoch - 54ms/step
# Epoch 70/100
# 727/727 - 38s - loss: 0.3273 - accuracy: 0.6627 - val_loss: 0.2580 - val_accuracy: 0.8030 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 71/100
# 727/727 - 38s - loss: 0.3261 - accuracy: 0.6679 - val_loss: 0.2599 - val_accuracy: 0.7957 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 72/100
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 727/727 - 38s - loss: 0.3280 - accuracy: 0.6656 - val_loss: 0.2554 - val_accuracy: 0.8054 - lr: 5.0000e-05 - 38s/epoch - 53ms/step
# Epoch 73/100
# 727/727 - 38s - loss: 0.3250 - accuracy: 0.6693 - val_loss: 0.2558 - val_accuracy: 0.8098 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 74/100
# 727/727 - 39s - loss: 0.3234 - accuracy: 0.6689 - val_loss: 0.2539 - val_accuracy: 0.8108 - lr: 2.5000e-05 - 39s/epoch - 54ms/step
# Epoch 75/100
# 727/727 - 39s - loss: 0.3241 - accuracy: 0.6710 - val_loss: 0.2545 - val_accuracy: 0.8153 - lr: 2.5000e-05 - 39s/epoch - 54ms/step
# Epoch 76/100
# 727/727 - 39s - loss: 0.3234 - accuracy: 0.6707 - val_loss: 0.2543 - val_accuracy: 0.8153 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 77/100
# 727/727 - 39s - loss: 0.3211 - accuracy: 0.6755 - val_loss: 0.2531 - val_accuracy: 0.8187 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 78/100
# 727/727 - 39s - loss: 0.3231 - accuracy: 0.6692 - val_loss: 0.2532 - val_accuracy: 0.8177 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 79/100
# 727/727 - 38s - loss: 0.3224 - accuracy: 0.6742 - val_loss: 0.2522 - val_accuracy: 0.8201 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 80/100
# 727/727 - 38s - loss: 0.3211 - accuracy: 0.6755 - val_loss: 0.2532 - val_accuracy: 0.8150 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 81/100
# 727/727 - 38s - loss: 0.3224 - accuracy: 0.6764 - val_loss: 0.2539 - val_accuracy: 0.8146 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 82/100
# 727/727 - 38s - loss: 0.3221 - accuracy: 0.6744 - val_loss: 0.2536 - val_accuracy: 0.8139 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 83/100
# 727/727 - 38s - loss: 0.3215 - accuracy: 0.6751 - val_loss: 0.2541 - val_accuracy: 0.8160 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 84/100
# 727/727 - 39s - loss: 0.3237 - accuracy: 0.6679 - val_loss: 0.2531 - val_accuracy: 0.8143 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 85/100
# 727/727 - 39s - loss: 0.3218 - accuracy: 0.6755 - val_loss: 0.2518 - val_accuracy: 0.8218 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 86/100
# 727/727 - 38s - loss: 0.3215 - accuracy: 0.6761 - val_loss: 0.2535 - val_accuracy: 0.8218 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 87/100
# 727/727 - 38s - loss: 0.3219 - accuracy: 0.6748 - val_loss: 0.2517 - val_accuracy: 0.8181 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 88/100
# 727/727 - 39s - loss: 0.3215 - accuracy: 0.6767 - val_loss: 0.2521 - val_accuracy: 0.8115 - lr: 2.5000e-05 - 39s/epoch - 53ms/step
# Epoch 89/100
# 727/727 - 38s - loss: 0.3209 - accuracy: 0.6770 - val_loss: 0.2510 - val_accuracy: 0.8205 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 90/100
# 727/727 - 38s - loss: 0.3214 - accuracy: 0.6748 - val_loss: 0.2518 - val_accuracy: 0.8181 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 91/100
# 727/727 - 38s - loss: 0.3214 - accuracy: 0.6759 - val_loss: 0.2524 - val_accuracy: 0.8167 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 92/100
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 727/727 - 38s - loss: 0.3185 - accuracy: 0.6843 - val_loss: 0.2524 - val_accuracy: 0.8205 - lr: 2.5000e-05 - 38s/epoch - 53ms/step
# Epoch 93/100
# 727/727 - 39s - loss: 0.3195 - accuracy: 0.6831 - val_loss: 0.2501 - val_accuracy: 0.8253 - lr: 1.2500e-05 - 39s/epoch - 54ms/step
# Epoch 94/100
# 727/727 - 38s - loss: 0.3193 - accuracy: 0.6807 - val_loss: 0.2498 - val_accuracy: 0.8273 - lr: 1.2500e-05 - 38s/epoch - 53ms/step
# Epoch 95/100
# 727/727 - 38s - loss: 0.3195 - accuracy: 0.6792 - val_loss: 0.2513 - val_accuracy: 0.8232 - lr: 1.2500e-05 - 38s/epoch - 52ms/step
# Epoch 96/100
# 727/727 - 38s - loss: 0.3189 - accuracy: 0.6828 - val_loss: 0.2498 - val_accuracy: 0.8246 - lr: 1.2500e-05 - 38s/epoch - 52ms/step
# Epoch 97/100
# 727/727 - 38s - loss: 0.3193 - accuracy: 0.6810 - val_loss: 0.2500 - val_accuracy: 0.8242 - lr: 1.2500e-05 - 38s/epoch - 52ms/step
# Epoch 98/100
# 727/727 - 38s - loss: 0.3176 - accuracy: 0.6814 - val_loss: 0.2498 - val_accuracy: 0.8260 - lr: 1.2500e-05 - 38s/epoch - 52ms/step
# Epoch 99/100
# 727/727 - 39s - loss: 0.3191 - accuracy: 0.6808 - val_loss: 0.2502 - val_accuracy: 0.8256 - lr: 1.2500e-05 - 39s/epoch - 53ms/step
# Epoch 100/100
# 727/727 - 38s - loss: 0.3184 - accuracy: 0.6793 - val_loss: 0.2501 - val_accuracy: 0.8253 - lr: 1.2500e-05 - 38s/epoch - 53ms/step

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

graphs(history)

saveModelWeights(model, test_acc)
# Out:
# 92/92 [==============================] - 2s 14ms/step - loss: 0.2587 - accuracy: 0.8088

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import classification_report

pred_test_labels = model.predict(x_test)

conf_mat = confusion_matrix(y_test.argmax(axis=1), pred_test_labels.argmax(axis=1))

emotions = {0: 'neutral', 1: 'happiness', 2: 'surprise', 3: 'sadness', 4: 'anger'}

#Plot confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=conf_mat,
                                colorbar=True,
                                show_normed=True,
                                show_absolute=False,
                                class_names=emotions.values(),
                                figsize=(8, 8))
fig.show()
#Print classifation report
print(classification_report(y_test.argmax(axis=1), pred_test_labels.argmax(axis=1), target_names=emotions.values()))
# Out:
# 92/92 [==============================] - 2s 11ms/step
#               precision    recall  f1-score   support
#
#      neutral       0.80      0.87      0.83      1142
#    happiness       0.87      0.91      0.89       844
#     surprise       0.87      0.79      0.82       376
#      sadness       0.61      0.51      0.56       312
#        anger       0.76      0.62      0.68       239
#
#     accuracy                           0.81      2913
#    macro avg       0.78      0.74      0.76      2913
# weighted avg       0.80      0.81      0.80      2913
# /var/folders/wx/c2fc49pd4s7fq23msz0ypksh0000gn/T/ipykernel_12537/3669170031.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
